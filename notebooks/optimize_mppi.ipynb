# %% [markdown]
# # MPPI Optimization
#
# 1/31. MPPI is an unbiased estimate of the score. Even if it requires lots of samples, these may be possible to evaluate in parallel. Because it's unbiased, it may also have an easier time dealing with constraints and avoiding the issues of imbalance between the kinetic energy and obstacle constraints.
